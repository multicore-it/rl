# %%
# -*- coding: utf-8 -*-
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import gym
import numpy as np
import random as rand

class Agent(object):
    def __init__(self, config_data):
        self.env = gym.make('CartPole-v1')
        self.state_size = self.env.observation_space.shape[0]
        self.action_size = self.env.action_space.n
        self.value_size = 1
        
        self.layer_num_actor = config_data['layer_num_actor']
        self.node_num_actor = config_data['node_num_actor']
        self.epochs_actor = config_data['epochs_actor']
        self.layer_num_critic = config_data['layer_num_critic']
        self.node_num_critic = config_data['node_num_critic']
        self.epochs_critic = config_data['epochs_critic']
        
        self.learning_rate_actor = config_data['learning_rate_actor']
        self.learning_rate_critic = config_data['learning_rate_critic']
        self.discount_rate = config_data['discount_rate']
        self.smooth_rate = config_data['smooth_rate']
        self.penalty = config_data['penalty']
        self.mini_batch_step_size = config_data['mini_batch_step_size']
        self.loss_clipping = config_data['loss_clipping']

        self.episode_num = 200
        self.moving_avg_size = 20
        
        self.model_actor = self.build_model_actor()
        self.model_critic = self.build_model_critic()
 
        self.states, self.states_next, self.action_matrixs, self.dones, self.action_probs, self.rewards = [],[],[],[],[],[]
        self.DUMMY_ACTION_MATRIX, self.DUMMY_ADVANTAGE = np.zeros((1,1,self.action_size)), np.zeros((1,1,self.value_size))
    
        self.reward_list= []
        self.count_list = []
        self.moving_avg_list = []
        
    class MyModel(tf.keras.Model):
        def train_step(self, data):
            in_datas, out_action_probs = data
            states, action_matrixs, advantages, loss_clipping = in_datas[0], in_datas[1], in_datas[2], in_datas[3]

            with tf.GradientTape() as tape:
                y_pred = self(states, training=True)
                new_policy = K.max(action_matrixs*y_pred, axis=-1)   
                old_policy = K.max(action_matrixs*out_action_probs, axis=-1)    
                r = new_policy/(old_policy)
                
                LOSS_CLIPPING = K.mean(loss_clipping)
                
                loss = -K.minimum(r*advantages, K.clip(r, 1-LOSS_CLIPPING, 1+LOSS_CLIPPING)*advantages)

            trainable_vars = self.trainable_variables
            gradients = tape.gradient(loss, trainable_vars)
            self.optimizer.apply_gradients(zip(gradients, trainable_vars))
            
    def build_model_actor(self):
        input_states = Input(shape=(1,self.state_size), name='input_states')
        input_action_matrixs = Input(shape=(1,self.action_size), name='input_action_matrixs')
        input_advantages = Input(shape=(1,self.value_size), name='input_advantages')
        input_loss_clipping = Input(shape=(1,self.value_size), name='input_loss_clipping')        
        
        x = (input_states)
        for i in range(1,self.layer_num_actor+1):            
            x = Dense(self.node_num_actor, activation="relu", kernel_initializer='glorot_normal')(x)
        out_actions = Dense(self.action_size, activation='softmax', name='output')(x)
        
        model = self.MyModel(inputs=[input_states, input_action_matrixs, input_advantages, input_loss_clipping],
                             outputs=out_actions)
        model.compile(optimizer=Adam(lr=self.learning_rate_actor))
        
        return model
    
    def build_model_critic(self):
        input_states = Input(shape=(1,self.state_size), name='input_states')
        
        x = (input_states)
        for i in range(1,self.layer_num_critic+1):
            x = Dense(self.node_num_critic, activation="relu", kernel_initializer='glorot_normal')(x)
        out_values = Dense(self.value_size, activation='linear', name='output')(x)
        
        model = tf.keras.models.Model(inputs=[input_states], outputs=[out_values])
        model.compile(optimizer=Adam(lr=self.learning_rate_critic),
#                       loss='mean_squared_error'
                      loss = "binary_crossentropy"
                     )
        return model

    def train(self):
        for episode in range(self.episode_num):

            state = self.env.reset()

            count, reward_tot = self.make_memory(episode, state)
            self.train_mini_batch()
            self.clear_memory()
            
            if count < 500:
                reward_tot = reward_tot-self.penalty
            
            self.reward_list.append(reward_tot)
            self.count_list.append(count)
            self.moving_avg_list.append(self.moving_avg(self.count_list,self.moving_avg_size))                
            

    def moving_avg(self, data, size=10):
        if len(data) > size:
            c = np.array(data[len(data)-size:len(data)]) 
        else:
            c = np.array(data) 
        return np.mean(c)
    
    def clear_memory(self):
        self.states, self.states_next, self.action_matrixs, self.done, self.action_probs, self.rewards = [],[],[],[],[],[]
        
    def make_memory(self, episode, state):
        reward_tot = 0
        count = 0
        reward = np.zeros(self.value_size)
        advantage = np.zeros(self.value_size)
        target = np.zeros(self.value_size)
        action_matrix = np.zeros(self.action_size)
        done = False
        
        while not done:
            count+=1

            state_t = np.reshape(self.normalize(state),[1, 1, self.state_size])
            action_matrix_t = np.reshape(action_matrix,[1, 1, self.action_size])
            
            action_prob = self.model_actor.predict([state_t, self.DUMMY_ACTION_MATRIX, self.DUMMY_ADVANTAGE])
            action = np.random.choice(self.action_size, 1, p=action_prob[0][0])[0]
            action_matrix = np.zeros(self.action_size) #초기화
            action_matrix[action] = 1

            state_next, reward, done, none = self.env.step(action)
            
            state_next_t = np.reshape(self.normalize(state_next),[1, 1, self.state_size])
            
            if count < 500 and done:
                reward = self.penalty 
        
            self.states.append(np.reshape(state_t, [1,self.state_size]))
            self.states_next.append(np.reshape(state_next_t, [1,self.state_size]))
            self.action_matrixs.append(np.reshape(action_matrix, [1,self.action_size]))
            self.dones.append(np.reshape(0 if done else 1, [1,self.value_size]))
            self.action_probs.append(np.reshape(action_prob, [1,self.action_size]))
            self.rewards.append(np.reshape(reward, [1,self.value_size]))
            
            if(count % self.mini_batch_step_size == 0):
                self.train_mini_batch()
                self.clear_memory()

            reward_tot += reward
            state = state_next
            
        return count, reward_tot
    
    def make_gae(self, values, values_next, rewards, dones):
        delta_adv, delta_tar, adv, target = 0, 0, 0, 0
        advantages = np.zeros(np.array(values).shape)
        targets = np.zeros(np.array(values).shape)
        for t in reversed(range(0, len(rewards))):
            delta_adv = rewards[t] + self.discount_rate * values_next[t] * dones[t] - values[t]
            delta_tar = rewards[t] + self.discount_rate * values_next[t] * dones[t]
            adv = delta_adv + self.smooth_rate *  self.discount_rate * dones[t] * adv
            target = delta_tar + self.smooth_rate * self.discount_rate * dones[t] * target
            advantages[t] = adv
            targets[t] = target
        return advantages, targets

    def normalize(self, x):
#         current_min = np.min(x)
#         current_max = np.max(x)
#         x_normed = (x - current_min) / (current_max - current_min)
#         current_mean = np.mean(x)
#         current_std = np.std(x)
#         x_normed = (x - current_mean) / current_std
#         return x_normed
        norm = np.linalg.norm(x)
        if norm == 0: 
            return x
        return x / norm

    def train_mini_batch(self):
        
        if len(self.states) == 0:
            return
        
        states_t = np.array(self.states)
        states_next_t = np.array(self.states_next)
        action_matrixs_t = np.array(self.action_matrixs)
        action_probs_t = np.array(self.action_probs)
        loss_clipping = [self.loss_clipping for j in range(len(self.states))]
        loss_clipping_t = np.reshape(loss_clipping, [len(self.states),1,1])
        
        values = self.model_critic.predict(states_t)
        values_next = self.model_critic.predict(states_next_t)
        
        advantages, targets = self.make_gae(values, values_next, self.rewards, self.dones)
        advantages_t = np.array(advantages)
        targets_t = np.array(targets)
        
        self.model_actor.fit([states_t, action_matrixs_t, advantages_t, loss_clipping_t], [action_probs_t], 
                             epochs=self.epochs_actor, verbose=0)
        self.model_critic.fit(states_t, targets_t, 
                              epochs=self.epochs_critic, verbose=0)       
        

if __name__ == "__main__":

    def random_select():
        config_data = {
            'layer_num_actor':rand.randint(1,2),
            'node_num_actor':rand.randint(12,128),
            'epochs_actor':rand.randint(3,6),
            'layer_num_critic':rand.randint(1,2),
            'node_num_critic':rand.randint(12,128),
            'epochs_critic':rand.randint(3,6),
            
            'learning_rate_actor' :rand.uniform(0.0001,0.001),
            'learning_rate_critic':rand.uniform(0.0001,0.001),
            'discount_rate'       :rand.uniform(0.9,0.99),
            'smooth_rate'       :rand.uniform(0.9,0.99),
            'penalty'             :rand.randint(-500,-10),
            'mini_batch_step_size':rand.randint(4,80),
            'loss_clipping'       :rand.uniform(0.1,0.3)
        }
        return config_data

    results = []
    print("***** start random search *****")        
    for i in range(100):
        config_data = random_select()
        agent = Agent(config_data)
        print("*config:", config_data)
        agent.train()
        result = []
        result.append(config_data)
        result.append(agent.moving_avg_list[len(agent.moving_avg_list)-1])
        result.append(np.mean(agent.reward_list))
        results.append(result)
        print("*result:", i, agent.moving_avg_list[len(agent.moving_avg_list)-1], np.mean(agent.reward_list))
        print("-"*100)
    print("***** end random search *****")
# Out:
# ***** start random search *****
# *config: {'layer_num_actor': 2, 'node_num_actor': 95, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 124, 'epochs_critic': 5, 'learning_rate_actor': 0.00018213203036520845, 'learning_rate_critic': 0.0005814962731170509, 'discount_rate': 0.962034926159223, 'smooth_rate': 0.9155998432226305, 'penalty': -101, 'mini_batch_step_size': 48, 'loss_clipping': 0.10779084820831981}
# *result: 0 321.8 155.71
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 36, 'epochs_actor': 4, 'layer_num_critic': 1, 'node_num_critic': 92, 'epochs_critic': 6, 'learning_rate_actor': 0.00014829843010839537, 'learning_rate_critic': 0.0009351140107065621, 'discount_rate': 0.9558029876140309, 'smooth_rate': 0.9556677031316966, 'penalty': -146, 'mini_batch_step_size': 64, 'loss_clipping': 0.2653178577438546}
# *result: 1 19.6 18.11
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 79, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 117, 'epochs_critic': 3, 'learning_rate_actor': 0.0005331998449545821, 'learning_rate_critic': 0.00015263631697136885, 'discount_rate': 0.9882695356654484, 'smooth_rate': 0.9117588412415741, 'penalty': -389, 'mini_batch_step_size': 29, 'loss_clipping': 0.28416359005681013}
# *result: 2 388.0 280.42
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor':
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 124, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 122, 'epochs_critic': 3, 'learning_rate_actor': 0.00016117563479511846, 'learning_rate_critic': 0.0002814835480838223, 'discount_rate': 0.92223293927836, 'smooth_rate': 0.9745485326825429, 'penalty': -187, 'mini_batch_step_size': 54, 'loss_clipping': 0.11133067809696187}
# *result: 12 459.4 164.615
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 77, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 114, 'epochs_critic': 4, 'learning_rate_actor': 0.0008101668026237482, 'learning_rate_critic': 0.0003283759393475845, 'discount_rate': 0.9627540731457029, 'smooth_rate': 0.9454886773906255, 'penalty': -12, 'mini_batch_step_size': 15, 'loss_clipping': 0.15654246784997988}
# *result: 13 254.95 234.955
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 20, 'epochs_actor': 5, 'layer_num_critic': 1, 'node_num_critic': 75, 'epochs_critic': 6, 'learning_rate_actor': 0.0002304972023898612, 'learning_rate_critic': 0.0008443414888158926, 'discount_rate': 0.9868825374955541, 'smooth_rate': 0.9621055499987834, 'penalty': -347, 'mini_batch_step_size': 57, 'loss_clipping': 0.2003820383427275}
# *result: 14 21.55 18.43
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 57, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 28, 'epochs_critic': 4, 'learning_rate_actor': 0.0007884302128160625, 'learning_rate_critic': 0.0002889826111540954, 'discount_rate': 0.90560356500552, 'smooth_rate': 0.9568140002102089, 'penalty': -430, 'mini_batch_step_size': 80, 'loss_clipping': 0.1411548704773604}
# *result: 15 231.2 83.84
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 40, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 93, 'epochs_critic': 4, 'learning_rate_actor': 0.00047861566943967546, 'learning_rate_critic': 0.00033034504409691124, 'discount_rate': 0.986534463473153, 'smooth_rate': 0.9644147670170182, 'penalty': -88, 'mini_batch_step_size': 67, 'loss_clipping': 0.24912898075341086}
# *result: 16 91.85 33.255
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 63, 'epochs_actor': 4, 'layer_num_critic': 1, 'node_num_critic': 39, 'epochs_critic': 4, 'learning_rate_actor': 0.0002824055347893398, 'learning_rate_critic': 0.0008988229258848825, 'discount_rate': 0.9245027675088912, 'smooth_rate': 0.9398157596871778, 'penalty': -78, 'mini_batch_step_size': 25, 'loss_clipping': 0.19948638955011896}
# *result: 17 459.0 262.805
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 109, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 96, 'epochs_critic': 6, 'learning_rate_actor': 0.00039962495194675445, 'learning_rate_critic': 0.0004101401034927788, 'discount_rate': 0.9362233690024067, 'smooth_rate': 0.9523845142002928, 'penalty': -486, 'mini_batch_step_size': 20, 'loss_clipping': 0.2898287538327621}
# *result: 18 210.0 186.41
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 70, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 43, 'epochs_critic': 5, 'learning_rate_actor': 0.0007527674635844694, 'learning_rate_critic': 0.0005498683953005938, 'discount_rate': 0.9797760848452484, 'smooth_rate': 0.920350079195602, 'penalty': -367, 'mini_batch_step_size': 25, 'loss_clipping': 0.21794043277829778}
# *result: 19 380.65 304.38
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 85, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 48, 'epochs_critic': 3, 'learning_rate_actor': 0.000262323764143421, 'learning_rate_critic': 0.0006601757492269588, 'discount_rate': 0.9209746471629415, 'smooth_rate': 0.9801179087352532, 'penalty': -316, 'mini_batch_step_size': 29, 'loss_clipping': 0.13620729232291978}
# *result: 20 410.3 139.82
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 74, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic':
 'epochs_actor': 5, 'layer_num_critic': 1, 'node_num_critic': 27, 'epochs_critic': 3, 'learning_rate_actor': 0.000718870436507516, 'learning_rate_critic': 0.0008364397603646222, 'discount_rate': 0.967556154290028, 'smooth_rate': 0.9365396583630076, 'penalty': -117, 'mini_batch_step_size': 74, 'loss_clipping': 0.1233424703211191}
# *result: 30 500.0 200.145
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 126, 'epochs_actor': 3, 'layer_num_critic': 2, 'node_num_critic': 53, 'epochs_critic': 5, 'learning_rate_actor': 0.0007398376276548852, 'learning_rate_critic': 0.000782161690928647, 'discount_rate': 0.9380889146797763, 'smooth_rate': 0.9575402594948629, 'penalty': -337, 'mini_batch_step_size': 21, 'loss_clipping': 0.10198071982559201}
# *result: 31 458.5 331.3
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 122, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 27, 'epochs_critic': 5, 'learning_rate_actor': 0.0004740604853055319, 'learning_rate_critic': 0.0002165452498323906, 'discount_rate': 0.9380458282962639, 'smooth_rate': 0.91504717799417, 'penalty': -253, 'mini_batch_step_size': 74, 'loss_clipping': 0.2764467323669336}
# *result: 32 32.85 27.67
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 32, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 93, 'epochs_critic': 4, 'learning_rate_actor': 0.0006029067888925772, 'learning_rate_critic': 0.0002117606702459449, 'discount_rate': 0.9881063693960008, 'smooth_rate': 0.9494194449528965, 'penalty': -51, 'mini_batch_step_size': 39, 'loss_clipping': 0.225177882405735}
# *result: 33 297.8 193.83
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 122, 'epochs_actor': 5, 'layer_num_critic': 1, 'node_num_critic': 34, 'epochs_critic': 4, 'learning_rate_actor': 0.0004384254974661672, 'learning_rate_critic': 0.0009945110711169125, 'discount_rate': 0.9005456621661532, 'smooth_rate': 0.9176040087832467, 'penalty': -455, 'mini_batch_step_size': 18, 'loss_clipping': 0.24984771255669938}
# *result: 34 495.45 320.325
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 91, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 86, 'epochs_critic': 6, 'learning_rate_actor': 0.0009922284531066255, 'learning_rate_critic': 0.0004222289162764212, 'discount_rate': 0.927134370489381, 'smooth_rate': 0.9250330130079243, 'penalty': -410, 'mini_batch_step_size': 34, 'loss_clipping': 0.14834049508549765}
# *result: 35 30.4 12.72
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 44, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 88, 'epochs_critic': 6, 'learning_rate_actor': 0.00013863569918386523, 'learning_rate_critic': 0.0006746888621120678, 'discount_rate': 0.9626504468649938, 'smooth_rate': 0.9279376461268555, 'penalty': -272, 'mini_batch_step_size': 59, 'loss_clipping': 0.1792374829945329}
# *result: 36 70.1 39.555
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 126, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 125, 'epochs_critic': 5, 'learning_rate_actor': 0.0009611602834401279, 'learning_rate_critic': 0.0005612625484735418, 'discount_rate': 0.9159540604158509, 'smooth_rate': 0.9552603864625631, 'penalty': -365, 'mini_batch_step_size': 7, 'loss_clipping': 0.183009151637499}
# *result: 37 10.4 110.985
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 68, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 61, 'epochs_critic': 3, 'learning_rate_actor': 0.0008907243716538601, 'learning_rate_critic': 0.000583379195925905, 'discount_rate': 0.9246355140596907, 'smooth_rate': 0.9816298791929788, 'penalty': -386, 'mini_batch_step_size': 4, 'loss_clipping': 0.20798428430264368}
# *result: 38 411.25 315.055
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 21, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic':
 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 121, 'epochs_critic': 5, 'learning_rate_actor': 0.00034305331427417343, 'learning_rate_critic': 0.0005495636947882123, 'discount_rate': 0.9683801305803816, 'smooth_rate': 0.9198257414433991, 'penalty': -193, 'mini_batch_step_size': 57, 'loss_clipping': 0.23278675909626068}
# *result: 58 14.7 15.18
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 21, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 19, 'epochs_critic': 4, 'learning_rate_actor': 0.0007183096847491918, 'learning_rate_critic': 0.00017439781059856637, 'discount_rate': 0.9105585494300247, 'smooth_rate': 0.9552003457441665, 'penalty': -331, 'mini_batch_step_size': 12, 'loss_clipping': 0.28710428039058367}
# *result: 59 399.55 258.58
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 116, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 20, 'epochs_critic': 4, 'learning_rate_actor': 0.0002891813816461097, 'learning_rate_critic': 0.000813515439582104, 'discount_rate': 0.988883865614971, 'smooth_rate': 0.9663356604242836, 'penalty': -231, 'mini_batch_step_size': 31, 'loss_clipping': 0.11104226911857525}
# *result: 60 372.55 147.025
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 68, 'epochs_actor': 6, 'layer_num_critic': 1, 'node_num_critic': 46, 'epochs_critic': 4, 'learning_rate_actor': 0.0009826098861003014, 'learning_rate_critic': 0.00038481455490110703, 'discount_rate': 0.9572221004355088, 'smooth_rate': 0.9840814796858662, 'penalty': -476, 'mini_batch_step_size': 64, 'loss_clipping': 0.248809549141781}
# *result: 61 9.8 11.095
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 127, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 100, 'epochs_critic': 5, 'learning_rate_actor': 0.0006371180003974053, 'learning_rate_critic': 0.00028969738248135833, 'discount_rate': 0.9392593886241439, 'smooth_rate': 0.9141097781692504, 'penalty': -381, 'mini_batch_step_size': 56, 'loss_clipping': 0.18033762451199079}
# *result: 62 434.85 201.94
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 65, 'epochs_actor': 5, 'layer_num_critic': 1, 'node_num_critic': 19, 'epochs_critic': 5, 'learning_rate_actor': 0.0008875923008204186, 'learning_rate_critic': 0.0007601755543288239, 'discount_rate': 0.9118871383881149, 'smooth_rate': 0.9770284230285338, 'penalty': -231, 'mini_batch_step_size': 48, 'loss_clipping': 0.16423935237564735}
# *result: 63 14.65 15.675
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 93, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 19, 'epochs_critic': 3, 'learning_rate_actor': 0.0008877618049417567, 'learning_rate_critic': 0.0006115922480731164, 'discount_rate': 0.9566173970526293, 'smooth_rate': 0.9243031687293641, 'penalty': -29, 'mini_batch_step_size': 13, 'loss_clipping': 0.182542048519676}
# *result: 64 129.1 187.215
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 57, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 69, 'epochs_critic': 6, 'learning_rate_actor': 0.0004336469620949757, 'learning_rate_critic': 0.0008601727894876552, 'discount_rate': 0.9462921568545178, 'smooth_rate': 0.9112296018279792, 'penalty': -140, 'mini_batch_step_size': 59, 'loss_clipping': 0.2017328057460958}
# *result: 65 177.85 198.115
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 122, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 61, 'epochs_critic': 5, 'learning_rate_actor': 0.000341420296934941, 'learning_rate_critic': 0.0006624090809603055, 'discount_rate': 0.9677256601169689, 'smooth_rate': 0.9458933236365561, 'penalty': -41, 'mini_batch_step_size': 61, 'loss_clipping': 0.17575179241046587}
# *result: 66 434.05 218.57
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 84, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 124, 'epochs_critic': 6, 'learning_rate_actor': 0.0008309637714930785, 'learning_rate_critic': 0.0009919019265390277, 'discount_rate': 0.9758081219845675, 'smooth_rate': 0.9615677041217322, 'penalty': -71, 'mini_batch_step_size': 73, 'loss_clipping': 0.22873382299134706}
# *result: 67 331.75 270.84
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 70, 'epochs_actor': 6, 'layer_num_critic': 1, 'node_num_critic': 87, 'epochs_critic': 4, 'learning_rate_actor': 0.0009924323099570471, 'learning_rate_critic': 0.0009906903012222765, 'discount_rate': 0.9883656445523892, 'smooth_rate': 0.9113275073505057, 'penalty': -228, 'mini_batch_step_size': 18, 'loss_clipping': 0.2326561972758618}
# *result: 68 364.35 282.545
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 36, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 123, 'epochs_critic': 4, 'learning_rate_actor': 0.0001833365617567458, 'learning_rate_critic': 0.0008189045547261388, 'discount_rate': 0.9585116603146989, 'smooth_rate': 0.9727772090941871, 'penalty': -300, 'mini_batch_step_size': 29, 'loss_clipping': 0.15274773134017336}
# *result: 69 32.5 24.585
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 87, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 47, 'epochs_critic': 3, 'learning_rate_actor': 0.00038981735929818104, 'learning_rate_critic': 0.00047645233348504593, 'discount_rate': 0.9382664755635846, 'smooth_rate': 0.9454305460753691, 'penalty': -357, 'mini_batch_step_size': 79, 'loss_clipping': 0.14171320045432506}
# *result: 70 9.65 12.82
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 93, 'epochs_actor': 3, 'layer_num_critic': 2, 'node_num_critic': 13, 'epochs_critic': 5, 'learning_rate_actor': 0.0006147100575517089, 'learning_rate_critic': 0.0002968861794859084, 'discount_rate': 0.9691978691375214, 'smooth_rate': 0.9094048266785005, 'penalty': -266, 'mini_batch_step_size': 37, 'loss_clipping': 0.24743521953658795}
# *result: 71 53.2 21.205
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 120, 'epochs_actor': 3, 'layer_num_critic': 2, 'node_num_critic': 67, 'epochs_critic': 3, 'learning_rate_actor': 0.00014675930877223586, 'learning_rate_critic': 0.0004978065405107127, 'discount_rate': 0.9145951155905415, 'smooth_rate': 0.9089986143765169, 'penalty': -231, 'mini_batch_step_size': 9, 'loss_clipping': 0.14328048400414292}
# *result: 72 487.95 239.625
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 57, 'epochs_actor': 4, 'layer_num_critic': 1, 'node_num_critic': 23, 'epochs_critic': 5, 'learning_rate_actor': 0.0009614869443768984, 'learning_rate_critic': 0.0008230623841809676, 'discount_rate': 0.9495779532366466, 'smooth_rate': 0.9109719092148643, 'penalty': -225, 'mini_batch_step_size': 23, 'loss_clipping': 0.18904303898916816}
# *result: 73 379.55 311.18
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 69, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 51, 'epochs_critic': 5, 'learning_rate_actor': 0.0006682361361712182, 'learning_rate_critic': 0.0005253500869156288, 'discount_rate': 0.9839773976987712, 'smooth_rate': 0.9105787738397946, 'penalty': -225, 'mini_batch_step_size': 66, 'loss_clipping': 0.12852161045672045}
# *result: 74 55.4 23.175
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 36, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 93, 'epochs_critic': 3, 'learning_rate_actor': 0.0007133951544839002, 'learning_rate_critic': 0.0003027275403603736, 'discount_rate': 0.9792858298196231, 'smooth_rate': 0.9233032760496022, 'penalty': -121, 'mini_batch_step_size': 56, 'loss_clipping': 0.2259524969065906}
# *result: 75 248.5 178.47
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 86, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 12, 'epochs_critic': 5, 'learning_rate_actor': 0.0004987547570887902, 'learning_rate_critic': 0.0005518318227359004, 'discount_rate': 0.9618429575661367, 'smooth_rate': 0.9887935588775858, 'penalty': -302, 'mini_batch_step_size': 19, 'loss_clipping': 0.2975822028571711}
# *result: 76 9.55 215.82
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 13, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 45, 'epochs_critic': 4, 'learning_rate_actor': 0.0006237279967164536, 'learning_rate_critic': 0.0005821269540017234, 'discount_rate': 0.9118774656142065, 'smooth_rate': 0.9308119679959684, 'penalty': -417, 'mini_batch_step_size': 32, 'loss_clipping': 0.12448591443085721}
# *result: 77 36.9 25.79
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 12, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 65, 'epochs_critic': 6, 'learning_rate_actor': 0.0008237026000277516, 'learning_rate_critic': 0.0009185657004003043, 'discount_rate': 0.9640685177278745, 'smooth_rate': 0.970890155199206, 'penalty': -223, 'mini_batch_step_size': 4, 'loss_clipping': 0.16228219209314668}
# *result: 78 380.85 85.13
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 117, 'epochs_actor': 4, 'layer_num_critic': 1, 'node_num_critic': 68, 'epochs_critic': 3, 'learning_rate_actor': 0.0001922188815027811, 'learning_rate_critic': 0.0008866799997647387, 'discount_rate': 0.9869102580375876, 'smooth_rate': 0.9534443886579802, 'penalty': -453, 'mini_batch_step_size': 76, 'loss_clipping': 0.18513988220286864}
# *result: 79 23.7 21.8
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 66, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 110, 'epochs_critic': 5, 'learning_rate_actor': 0.0006170280341249814, 'learning_rate_critic': 0.000492549534518446, 'discount_rate': 0.9738089896475505, 'smooth_rate': 0.9271849991376706, 'penalty': -476, 'mini_batch_step_size': 37, 'loss_clipping': 0.2476931205532228}
# *result: 80 467.3 240.515
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 114, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 109, 'epochs_critic': 3, 'learning_rate_actor': 0.0002442572864511702, 'learning_rate_critic': 0.0002286450716248216, 'discount_rate': 0.9104103860801598, 'smooth_rate': 0.9383046451821222, 'penalty': -286, 'mini_batch_step_size': 50, 'loss_clipping': 0.24597685400081165}
# *result: 81 482.6 163.1
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 118, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 51, 'epochs_critic': 4, 'learning_rate_actor': 0.0005501557308490698, 'learning_rate_critic': 0.00039253997844456096, 'discount_rate': 0.9097336360596163, 'smooth_rate': 0.983642311745383, 'penalty': -330, 'mini_batch_step_size': 31, 'loss_clipping': 0.22165367010873038}
# *result: 82 433.45 292.725
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 23, 'epochs_actor': 5, 'layer_num_critic': 1, 'node_num_critic': 17, 'epochs_critic': 4, 'learning_rate_actor': 0.000760083158462909, 'learning_rate_critic': 0.00085697088497177, 'discount_rate': 0.9547110371059945, 'smooth_rate': 0.9154120299028222, 'penalty': -194, 'mini_batch_step_size': 35, 'loss_clipping': 0.12205800151501855}
# *result: 83 368.1 203.82
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 15, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 73, 'epochs_critic': 3, 'learning_rate_actor': 0.0002470721155645719, 'learning_rate_critic': 0.00019647291562658106, 'discount_rate': 0.9010512867674603, 'smooth_rate': 0.960531875193141, 'penalty': -388, 'mini_batch_step_size': 27, 'loss_clipping': 0.2488613243068812}
# *result: 84 28.25 20.83
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 71, 'epochs_actor': 4, 'layer_num_critic': 1, 'node_num_critic': 91, 'epochs_critic': 3, 'learning_rate_actor': 0.00016235844149494155, 'learning_rate_critic': 0.0004207387202641619, 'discount_rate': 0.9201381193881122, 'smooth_rate': 0.9012635156485259, 'penalty': -380, 'mini_batch_step_size': 50, 'loss_clipping': 0.29710253736210146}
# *result: 85 25.75 17.525
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 42, 'epochs_actor': 3, 'layer_num_critic': 2, 'node_num_critic': 91, 'epochs_critic': 5, 'learning_rate_actor': 0.0005152868337933054, 'learning_rate_critic': 0.0005527241057957348, 'discount_rate': 0.9598944426452807, 'smooth_rate': 0.9281545177586177, 'penalty': -270, 'mini_batch_step_size': 6, 'loss_clipping': 0.193794650939755}
# *result: 86 463.9 296.545
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 65, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 69, 'epochs_critic': 4, 'learning_rate_actor': 0.0005284786675362755, 'learning_rate_critic': 0.00040453926070705364, 'discount_rate': 0.9273431077576556, 'smooth_rate': 0.9258891884544557, 'penalty': -498, 'mini_batch_step_size': 25, 'loss_clipping': 0.21937249686807503}
# *result: 87 407.85 287.06
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 29, 'epochs_actor': 6, 'layer_num_critic': 1, 'node_num_critic': 90, 'epochs_critic': 4, 'learning_rate_actor': 0.0005008156472417013, 'learning_rate_critic': 0.0006211480791888205, 'discount_rate': 0.9483340183677123, 'smooth_rate': 0.941130522473172, 'penalty': -185, 'mini_batch_step_size': 47, 'loss_clipping': 0.12284158183433408}
# *result: 88 13.9 12.375
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 76, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 32, 'epochs_critic': 3, 'learning_rate_actor': 0.000855418151234721, 'learning_rate_critic': 0.0005646195494911171, 'discount_rate': 0.9216298071210814, 'smooth_rate': 0.9425985391987551, 'penalty': -161, 'mini_batch_step_size': 28, 'loss_clipping': 0.2417759070465442}
# *result: 89 326.2 257.515
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 93, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 37, 'epochs_critic': 5, 'learning_rate_actor': 0.000586356945546793, 'learning_rate_critic': 0.00030803376515718396, 'discount_rate': 0.9774437108709556, 'smooth_rate': 0.9893911117316467, 'penalty': -356, 'mini_batch_step_size': 52, 'loss_clipping': 0.23591132894802028}
# *result: 90 437.8 134.945
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 35, 'epochs_actor': 3, 'layer_num_critic': 2, 'node_num_critic': 109, 'epochs_critic': 6, 'learning_rate_actor': 0.0006889426463276539, 'learning_rate_critic': 0.000838960901441995, 'discount_rate': 0.9430550331716022, 'smooth_rate': 0.9638644498888524, 'penalty': -408, 'mini_batch_step_size': 17, 'loss_clipping': 0.28533427415394297}
# *result: 91 479.35 187.29
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 117, 'epochs_actor': 6, 'layer_num_critic': 2, 'node_num_critic': 36, 'epochs_critic': 5, 'learning_rate_actor': 0.00010478841492551464, 'learning_rate_critic': 0.0007891746701166049, 'discount_rate': 0.9481997265822395, 'smooth_rate': 0.920310433706161, 'penalty': -191, 'mini_batch_step_size': 16, 'loss_clipping': 0.2367961289427224}
# *result: 92 306.35 139.64
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 75, 'epochs_actor': 4, 'layer_num_critic': 1, 'node_num_critic': 107, 'epochs_critic': 4, 'learning_rate_actor': 0.0005331533733799235, 'learning_rate_critic': 0.0009797676016362119, 'discount_rate': 0.9812446965107471, 'smooth_rate': 0.9416453249788767, 'penalty': -138, 'mini_batch_step_size': 25, 'loss_clipping': 0.12760508050477787}
# *result: 93 444.9 151.515
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 48, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 32, 'epochs_critic': 5, 'learning_rate_actor': 0.00042500382766494664, 'learning_rate_critic': 0.00016052957064095785, 'discount_rate': 0.9373438721133962, 'smooth_rate': 0.9021199604091764, 'penalty': -52, 'mini_batch_step_size': 38, 'loss_clipping': 0.240896931054798}
# *result: 94 407.15 174.9
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 94, 'epochs_actor': 5, 'layer_num_critic': 1, 'node_num_critic': 25, 'epochs_critic': 6, 'learning_rate_actor': 0.00021419312892618993, 'learning_rate_critic': 0.0006293846422970487, 'discount_rate': 0.9207110640312844, 'smooth_rate': 0.9145984775834117, 'penalty': -316, 'mini_batch_step_size': 8, 'loss_clipping': 0.1281804631315251}
# *result: 95 480.4 210.805
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 104, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 70, 'epochs_critic': 4, 'learning_rate_actor': 0.0007633079262687019, 'learning_rate_critic': 0.00030153377673188724, 'discount_rate': 0.9551184301197241, 'smooth_rate': 0.9239368466900584, 'penalty': -38, 'mini_batch_step_size': 8, 'loss_clipping': 0.10085697891806587}
# *result: 96 493.25 326.11
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 1, 'node_num_actor': 19, 'epochs_actor': 5, 'layer_num_critic': 1, 'node_num_critic': 30, 'epochs_critic': 3, 'learning_rate_actor': 0.0005884861891987373, 'learning_rate_critic': 0.00043778988165748937, 'discount_rate': 0.9380430582342352, 'smooth_rate': 0.9065591762670321, 'penalty': -402, 'mini_batch_step_size': 19, 'loss_clipping': 0.29622934908690624}
# *result: 97 406.8 224.735
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 29, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 81, 'epochs_critic': 4, 'learning_rate_actor': 0.0002286773961160532, 'learning_rate_critic': 0.0005821629265675623, 'discount_rate': 0.9578698706725295, 'smooth_rate': 0.9309315729377983, 'penalty': -424, 'mini_batch_step_size': 32, 'loss_clipping': 0.11537382321368204}
# *result: 98 149.4 49.46
# ----------------------------------------------------------------------------------------------------
# *config: {'layer_num_actor': 2, 'node_num_actor': 90, 'epochs_actor': 3, 'layer_num_critic': 1, 'node_num_critic': 25, 'epochs_critic': 4, 'learning_rate_actor': 0.00042486048723834645, 'learning_rate_critic': 0.00020446135647386553, 'discount_rate': 0.9676650193263128, 'smooth_rate': 0.95982013706074, 'penalty': -437, 'mini_batch_step_size': 48, 'loss_clipping': 0.2000142797197637}
# *result: 99 139.75 94.68
# ----------------------------------------------------------------------------------------------------
# ***** end random search *****

# %%
avg_list = []
for i in range(0, 100):
    avg_list.append([results[i][2], i])
avg_list.sort(reverse=True)    
avg_list
# Out:
# [[336.015, 27],
#  [331.3, 31],
#  [326.11, 96],
#  [320.325, 34],
#  [318.81, 41],
#  [315.055, 38],
#  [311.18, 73],
#  [310.87, 26],
#  [304.38, 19],
#  [304.09, 40],
#  [299.015, 4],
#  [296.545, 86],
#  [292.725, 82],
#  [287.06, 87],
#  [282.545, 68],
#  [280.42, 2],
#  [280.075, 23],
#  [275.755, 43],
#  [271.585, 29],
#  [270.84, 67],
#  [264.11, 54],
#  [262.805, 17],
#  [259.73, 10],
#  [258.58, 59],
#  [257.99, 22],
#  [257.515, 89],
#  [248.595, 47],
#  [240.515, 80],
#  [239.625, 72],
#  [237.525, 3],
#  [234.955, 13],
#  [229.89, 24],
#  [228.15, 5],
#  [224.735, 97],
#  [220.05, 9],
#  [218.57, 66],
#  [218.525, 21],
#  [217.59, 46],
#  [216.41, 6],
#  [215.82, 76],
#  [210.805, 95],
#  [203.82, 83],
#  [201.94, 62],
#  [200.145, 30],
#  [198.115, 65],
#  [196.175, 49],
#  [193.83, 33],
#  [187.29, 91],
#  [187.215, 64],
#  [186.41, 18],
#  [178.47, 75],
#  [174.9, 94],
#  [168.69, 11],
#  [164.615, 12],
#  [163.1, 81],
#  [155.71, 0],
#  [151.515, 93],
#  [147.025, 60],
#  [139.82, 20],
#  [139.64, 92],
#  [134.945, 90],
#  [128.47, 51],
#  [120.77, 57],
#  [110.985, 37],
#  [108.12, 48],
#  [99.97, 53],
#  [94.68, 99],
#  [85.13, 78],
#  [83.84, 15],
#  [76.89, 44],
#  [49.46, 98],
#  [39.555, 36],
#  [33.41, 45],
#  [33.255, 16],
#  [29.575, 42],
#  [29.31, 39],
#  [28.485, 7],
#  [27.67, 32],
#  [25.79, 77],
#  [24.585, 69],
#  [23.415, 56],
#  [23.32, 8],
#  [23.175, 74],
#  [22.875, 55],
#  [22.075, 28],
#  [21.8, 79],
#  [21.205, 71],
#  [20.83, 84],
#  [19.875, 50],
#  [18.43, 14],
#  [18.11, 1],
#  [17.525, 85],
#  [17.01, 52],
#  [15.675, 63],
#  [15.18, 58],
#  [14.075, 25],
#  [12.82, 70],
#  [12.72, 35],
#  [12.375, 88],
#  [11.095, 61]]

# %%
print(results[27])
print(results[31])
print(results[96])
# Out:
# [{'layer_num_actor': 1, 'node_num_actor': 103, 'epochs_actor': 4, 'layer_num_critic': 2, 'node_num_critic': 125, 'epochs_critic': 3, 'learning_rate_actor': 0.0005344386158424651, 'learning_rate_critic': 0.00016820136716122927, 'discount_rate': 0.9257023950429729, 'smooth_rate': 0.9524677200660574, 'penalty': -241, 'mini_batch_step_size': 16, 'loss_clipping': 0.11072764945067409}, 457.1, 336.015]
# [{'layer_num_actor': 1, 'node_num_actor': 126, 'epochs_actor': 3, 'layer_num_critic': 2, 'node_num_critic': 53, 'epochs_critic': 5, 'learning_rate_actor': 0.0007398376276548852, 'learning_rate_critic': 0.000782161690928647, 'discount_rate': 0.9380889146797763, 'smooth_rate': 0.9575402594948629, 'penalty': -337, 'mini_batch_step_size': 21, 'loss_clipping': 0.10198071982559201}, 458.5, 331.3]
# [{'layer_num_actor': 1, 'node_num_actor': 104, 'epochs_actor': 5, 'layer_num_critic': 2, 'node_num_critic': 70, 'epochs_critic': 4, 'learning_rate_actor': 0.0007633079262687019, 'learning_rate_critic': 0.00030153377673188724, 'discount_rate': 0.9551184301197241, 'smooth_rate': 0.9239368466900584, 'penalty': -38, 'mini_batch_step_size': 8, 'loss_clipping': 0.10085697891806587}, 493.25, 326.11]

# %%
count_300 = 0
for i in range(0, 100):
    if(results[i][2] >= 300):
        count_300 = count_300+1
print("count_400:", count_300)
# Out:
# count_400: 10
